-- %% [markdown]
-- # [dbo].[__EFMigrationsHistory]

-- %%
USE [AdminDashBoard]
GO

-- %%
/****** Object:  Table [dbo].[__EFMigrationsHistory]    Script Date: 13/05/2024 10:26:25 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[__EFMigrationsHistory](
	[MigrationId] [nvarchar](150) NOT NULL,
	[ProductVersion] [nvarchar](32) NOT NULL,
 CONSTRAINT [PK___EFMigrationsHistory] PRIMARY KEY CLUSTERED 
(
	[MigrationId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AccountUser]

-- %%
/****** Object:  Table [dbo].[AccountUser]    Script Date: 13/05/2024 10:26:25 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AccountUser](
	[user_id] [int] IDENTITY(1,1) NOT NULL,
	[first_name] [nvarchar](100) NULL,
	[last_name] [nvarchar](100) NULL,
	[is_active] [bit] NULL,
	[department] [nvarchar](50) NULL,
	[user_name] [nvarchar](256) NULL,
	[email] [nvarchar](256) NULL,
	[password_hash] [nvarchar](max) NULL,
	[phone_number] [varchar](50) NULL,
 CONSTRAINT [PK_AspNetUsers] PRIMARY KEY CLUSTERED 
(
	[user_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[GroupPermissions]

-- %%
/****** Object:  Table [dbo].[GroupPermissions]    Script Date: 13/05/2024 10:26:25 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[GroupPermissions](
	[group_id] [int] NOT NULL,
	[permission_id] [int] NOT NULL,
	[is_enable] [bit] NULL,
 CONSTRAINT [PK_GroupPermissions] PRIMARY KEY CLUSTERED 
(
	[group_id] ASC,
	[permission_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Groups]

-- %%
/****** Object:  Table [dbo].[Groups]    Script Date: 13/05/2024 10:26:25 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Groups](
	[group_id] [int] IDENTITY(1,1) NOT NULL,
	[groupName] [varchar](50) NOT NULL,
 CONSTRAINT [PK_Groups] PRIMARY KEY CLUSTERED 
(
	[group_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Permissions]

-- %%
/****** Object:  Table [dbo].[Permissions]    Script Date: 13/05/2024 10:26:25 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Permissions](
	[permission_id] [int] IDENTITY(1,1) NOT NULL,
	[permisstion_name] [varchar](50) NULL,
	[description] [nvarchar](max) NULL,
 CONSTRAINT [PK_Permissions] PRIMARY KEY CLUSTERED 
(
	[permission_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[UserGroups]

-- %%
/****** Object:  Table [dbo].[UserGroups]    Script Date: 13/05/2024 10:26:25 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[UserGroups](
	[user_id] [int] NOT NULL,
	[group_id] [int] NOT NULL,
	[is_enable] [bit] NULL,
 CONSTRAINT [PK_UserGroups] PRIMARY KEY CLUSTERED 
(
	[user_id] ASC,
	[group_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[__EFMigrationsHistory]

-- %%
INSERT [dbo].[__EFMigrationsHistory] ([MigrationId], [ProductVersion]) VALUES (N'20240505065711_createAd', N'8.0.3')
INSERT [dbo].[__EFMigrationsHistory] ([MigrationId], [ProductVersion]) VALUES (N'20240506050535_createAd', N'8.0.3')
INSERT [dbo].[__EFMigrationsHistory] ([MigrationId], [ProductVersion]) VALUES (N'20240508042230_createV1', N'8.0.3')
GO

-- %% [markdown]
-- # [dbo].[AccountUser]

-- %%
SET IDENTITY_INSERT [dbo].[AccountUser] ON 
INSERT [dbo].[AccountUser] ([user_id], [first_name], [last_name], [is_active], [department], [user_name], [email], [password_hash], [phone_number]) VALUES (1, N'Hello', N'Word', 1, N'IT', N'kiki123', N'namne@gmail.com', N'$2a$11$GbJpblC/CgmhFiEnpOsw6eeoSH3pMwE0WSWXlXtZqbOeuQXNig/vW', N'123456789')
INSERT [dbo].[AccountUser] ([user_id], [first_name], [last_name], [is_active], [department], [user_name], [email], [password_hash], [phone_number]) VALUES (2, N'mom', N'my', 1, N'string', N'string', N'string', N'$2a$11$lkn2e94xn23QbXS.XFqzteXeP733VYLWXWGFp/MnGiBkQClj/0QhG', N'string')
SET IDENTITY_INSERT [dbo].[AccountUser] OFF
GO

-- %% [markdown]
-- # [dbo].[GroupPermissions]

-- %%
INSERT [dbo].[GroupPermissions] ([group_id], [permission_id], [is_enable]) VALUES (1, 1, 0)
INSERT [dbo].[GroupPermissions] ([group_id], [permission_id], [is_enable]) VALUES (1, 2, 1)
INSERT [dbo].[GroupPermissions] ([group_id], [permission_id], [is_enable]) VALUES (1, 3, 1)
INSERT [dbo].[GroupPermissions] ([group_id], [permission_id], [is_enable]) VALUES (1, 4, 0)
INSERT [dbo].[GroupPermissions] ([group_id], [permission_id], [is_enable]) VALUES (2, 1, 1)
INSERT [dbo].[GroupPermissions] ([group_id], [permission_id], [is_enable]) VALUES (2, 2, 1)
INSERT [dbo].[GroupPermissions] ([group_id], [permission_id], [is_enable]) VALUES (2, 3, 1)
INSERT [dbo].[GroupPermissions] ([group_id], [permission_id], [is_enable]) VALUES (2, 4, 1)
INSERT [dbo].[GroupPermissions] ([group_id], [permission_id], [is_enable]) VALUES (4, 1, 1)
INSERT [dbo].[GroupPermissions] ([group_id], [permission_id], [is_enable]) VALUES (5, 1, 1)
INSERT [dbo].[GroupPermissions] ([group_id], [permission_id], [is_enable]) VALUES (5, 2, 1)
INSERT [dbo].[GroupPermissions] ([group_id], [permission_id], [is_enable]) VALUES (5, 3, 1)
INSERT [dbo].[GroupPermissions] ([group_id], [permission_id], [is_enable]) VALUES (6, 1, 1)
INSERT [dbo].[GroupPermissions] ([group_id], [permission_id], [is_enable]) VALUES (6, 2, 1)
INSERT [dbo].[GroupPermissions] ([group_id], [permission_id], [is_enable]) VALUES (6, 3, 1)
INSERT [dbo].[GroupPermissions] ([group_id], [permission_id], [is_enable]) VALUES (6, 4, 1)
GO

-- %% [markdown]
-- # [dbo].[Groups]

-- %%
SET IDENTITY_INSERT [dbo].[Groups] ON 
INSERT [dbo].[Groups] ([group_id], [groupName]) VALUES (1, N'HR')
INSERT [dbo].[Groups] ([group_id], [groupName]) VALUES (2, N'PayRoll')
INSERT [dbo].[Groups] ([group_id], [groupName]) VALUES (3, N'admin')
INSERT [dbo].[Groups] ([group_id], [groupName]) VALUES (4, N'admin')
INSERT [dbo].[Groups] ([group_id], [groupName]) VALUES (5, N'admin')
INSERT [dbo].[Groups] ([group_id], [groupName]) VALUES (6, N'demo')
SET IDENTITY_INSERT [dbo].[Groups] OFF
GO

-- %% [markdown]
-- # [dbo].[Permissions]

-- %%
SET IDENTITY_INSERT [dbo].[Permissions] ON 
INSERT [dbo].[Permissions] ([permission_id], [permisstion_name], [description]) VALUES (1, N'Read', N'Allows read-only access')
INSERT [dbo].[Permissions] ([permission_id], [permisstion_name], [description]) VALUES (2, N'Write', N'Allows write access')
INSERT [dbo].[Permissions] ([permission_id], [permisstion_name], [description]) VALUES (3, N'Delete', N'Allows deletion access')
INSERT [dbo].[Permissions] ([permission_id], [permisstion_name], [description]) VALUES (4, N'Admin', N'Admin privileges')
SET IDENTITY_INSERT [dbo].[Permissions] OFF
GO

-- %% [markdown]
-- # [dbo].[UserGroups]

-- %%
INSERT [dbo].[UserGroups] ([user_id], [group_id], [is_enable]) VALUES (1, 1, 1)
INSERT [dbo].[UserGroups] ([user_id], [group_id], [is_enable]) VALUES (2, 2, 1)
INSERT [dbo].[UserGroups] ([user_id], [group_id], [is_enable]) VALUES (2, 3, 1)
GO

-- %% [markdown]
-- # [FK_GroupPermissions_Groups]

-- %%
ALTER TABLE [dbo].[GroupPermissions]  WITH CHECK ADD  CONSTRAINT [FK_GroupPermissions_Groups] FOREIGN KEY([group_id])
REFERENCES [dbo].[Groups] ([group_id])
GO
ALTER TABLE [dbo].[GroupPermissions] CHECK CONSTRAINT [FK_GroupPermissions_Groups]
GO

-- %% [markdown]
-- # [FK_GroupPermissions_Permissions]

-- %%
ALTER TABLE [dbo].[GroupPermissions]  WITH CHECK ADD  CONSTRAINT [FK_GroupPermissions_Permissions] FOREIGN KEY([permission_id])
REFERENCES [dbo].[Permissions] ([permission_id])
GO
ALTER TABLE [dbo].[GroupPermissions] CHECK CONSTRAINT [FK_GroupPermissions_Permissions]
GO

-- %% [markdown]
-- # [FK_UserGroups_AccountUser]

-- %%
ALTER TABLE [dbo].[UserGroups]  WITH CHECK ADD  CONSTRAINT [FK_UserGroups_AccountUser] FOREIGN KEY([user_id])
REFERENCES [dbo].[AccountUser] ([user_id])
GO
ALTER TABLE [dbo].[UserGroups] CHECK CONSTRAINT [FK_UserGroups_AccountUser]
GO

-- %% [markdown]
-- # [FK_UserGroups_Groups]

-- %%
ALTER TABLE [dbo].[UserGroups]  WITH CHECK ADD  CONSTRAINT [FK_UserGroups_Groups] FOREIGN KEY([group_id])
REFERENCES [dbo].[Groups] ([group_id])
GO
ALTER TABLE [dbo].[UserGroups] CHECK CONSTRAINT [FK_UserGroups_Groups]
GO
